# %%
# %matplotlib inline

import matplotlib.pyplot as plt

import numpy as np
import torch
from torch.nn.parameter import Parameter
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import networkx as nx
import time
import os.path as osp
from collections import defaultdict
import pandas as pd
# import xlsxwriter
from torch_geometric.nn import GCNConv,GATConv, SGConv, BatchNorm
torch.manual_seed(0)

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
torch.set_printoptions(precision=10)
gra_train = "scale"
path_train = "data/"+gra_train
path_test = "data/"

dataset = "cit-DBLP"

# %%
def data_process(g, mode="test"):
  
    adj = list(g.edges())
    m = g.number_of_nodes()

    features = torch.zeros(size=(m,1)).float()
    
    print("No.of nodes = ",m)
    print("No.of edges = ",g.number_of_edges())

    for u,_ in adj:
        features[u,0]+=1

    features = features/max(features)
    adj = torch.LongTensor(adj).t().contiguous()
 
    if mode == "train":
        
        adj_mat = torch.from_numpy(nx.to_numpy_array(g))
        adj_mat = F.normalize(adj_mat, p=1,dim=1).float()
        
        return adj.to(device), features.to(device), adj_mat.to(device)
    
    else:
        return adj.to(device), features.to(device)

# %%
def eigen_vector_calc(adj_mat, y):
    
    z = torch.spmm(adj_mat,y)
    y = y / (torch.linalg.norm(y))
    z = z/ (torch.linalg.norm(z))
    
    return y,z

# %%
class Model(nn.Module):
    def __init__(self, nin, nhid1, nout, hid_l, out_l=1):
        super(Model, self).__init__()
        
        self.gc1 = GCNConv(in_channels= nin, out_channels= nhid1)
        self.bc1 = BatchNorm(nhid1)
        self.gc2 = GCNConv(in_channels= nhid1, out_channels= nout)
        self.bc2 = BatchNorm(nhid1)
        self.lay1 = nn.Linear(nout ,hid_l)
        self.l0 = nn.Linear(hid_l,hid_l)
        self.lb0 = nn.BatchNorm1d(hid_l)
        self.l1 = nn.Linear(hid_l,hid_l)
        self.lb1 = nn.BatchNorm1d(hid_l)
        self.lay2 = nn.Linear(hid_l ,out_l)
        self.active1 = nn.LeakyReLU(0.1)
        
        with torch.no_grad():
            self.gc1.weight = Parameter(nn.init.uniform_(torch.empty(nin,nhid1),a=0.0,b=1.0))
            self.gc1.bias = Parameter(nn.init.uniform_(torch.empty(nhid1),a=0.0,b=1.0))
            self.gc2.weight = Parameter(nn.init.uniform_(torch.empty(nhid1,nout),a=0.0,b=1.0))
            self.gc2.bias = Parameter(nn.init.uniform_(torch.empty(nout),a=0.0,b=1.0))
            self.lay1.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, nout ),a=0.0,b=1.0))
            self.l0.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, hid_l),a=0.0,b=1.0))
            self.l1.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, hid_l),a=0.0,b=1.0))
            self.lay2.weight = Parameter(nn.init.uniform_(torch.empty(out_l,hid_l),a=0.0,b=1.0))


    def forward(self, x, adj):
        x = self.gc1(x, adj)
        x = self.bc1(x)
        x = self.gc2(x, adj)
        x = self.bc2(x)
        x = self.lay1(x)
        x = self.l0(x)
        x = self.lb0(x)
        x = self.l1(x)
        x = self.lb1(x)
        x = self.lay2(x)
        
        return self.active1(x)

# %%
def train_model(epoch):
    model.train()
    optimizer.zero_grad()
    t = time.time()
    y = model(features,adj)
    
    y,z = eigen_vector_calc(adj_mat, y)
    
    loss1 = nn.MSELoss()(y,z)
    loss2 = -y.abs().mean()
    loss_train = loss1 + loss2
    loss_temp.append(loss_train.cpu().detach())
    
    loss_train.backward(retain_graph=True)
    optimizer.step()
    
    if epoch%50==0:
        print("MSE loss = ",loss1,"\t","Mean Loss = ",loss2)
        print('Epoch: {:04d}'.format(epoch+1),
                  'loss_train: {:.10f}'.format(loss_train.item()),
                  'time: {:.4f}s'.format(time.time() - t))
        
    
    return y

# %%
if __name__=="__main__":
    
    #Training

    loss_plot = []
    
    model= Model(nin = 1, nhid1=128, nout=128, hid_l=64, out_l=1).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr = 0.001)
    #flag = False
    g = nx.read_edgelist(osp.join(path_test, dataset+".edgelist"),nodetype=int)
    no_of_nodes = g.number_of_nodes()
    
    for i in range(30):
        print("\n\n Graph number",i,"\n","-"*120)
        #if flag: break
        
        samples = np.random.randint(low=0, high=no_of_nodes)

        g_subgraph = nx.bfs_tree(g, source=samples, depth_limit=2)
        map = dict( list(zip(list(g_subgraph.nodes()), list(range(g_subgraph.number_of_nodes())))))
        g_subgraph = g.subgraph(g_subgraph)
        g_subgraph = nx.relabel_nodes(g_subgraph,map)
        #g = nx.read_edgelist(osp.join(path_train,gra_train+"_1k/"+gra_train+"1k_"+str(i)),nodetype=int)
        adj,features,adj_mat = data_process(g_subgraph ,mode="train")
        print("adj_list = ",adj.shape,"adj_mat = ",adj_mat.shape)

        loss_temp=[]
        net_time = time.time()
        
        for ep in range(150):
            y = train_model(ep)
            if ep%50==0:
                print("Time Net = ",time.time()-net_time,"\n\n")
                '''
                print("{:^10}".format("-------Validation-------"))
                l5, l10, l15, l20 = [],[],[],[]
                test(g)
                if l5[0]>0.5 and l10>0.55:
                  flag = True
                  break
                '''
        # loss_plot.append((np.mean(loss_temp), i))
# Out:
#  Graph number 0
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  1257
# No.of edges =  5339
# adj_list =  torch.Size([2, 5339]) adj_mat =  torch.Size([1257, 1257])
# MSE loss =  tensor(0.0008247283, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0184346456, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0176099166 time: 15.2339s
# Time Net =  15.24394154548645
#
#
# MSE loss =  tensor(0.0007082235, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0218561590, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0211479347 time: 0.2768s
# Time Net =  18.54560375213623
#
#
# MSE loss =  tensor(0.0006757395, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0219384357, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0212626960 time: 0.2356s
# Time Net =  21.813276290893555
#
#
#
#
#  Graph number 1
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  669
# No.of edges =  2981
# adj_list =  torch.Size([2, 2981]) adj_mat =  torch.Size([669, 669])
# MSE loss =  tensor(0.0020721832, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0300795492, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0280073658 time: 0.2680s
# Time Net =  0.2680046558380127
#
#
# MSE loss =  tensor(0.0016210952, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0312050674, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0295839719 time: 0.2860s
# Time Net =  3.2106130123138428
#
#
# MSE loss =  tensor(0.0013604875, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0317257755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0303652883 time: 0.2610s
# Time Net =  6.038336277008057
#
#
#
#
#  Graph number 2
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  11
# No.of edges =  16
# adj_list =  torch.Size([2, 16]) adj_mat =  torch.Size([11, 11])
# MSE loss =  tensor(0.0307529140, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2662383616, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2354854494 time: 0.2420s
# Time Net =  0.24199986457824707
#
#
# MSE loss =  tensor(0.0001293355, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.3013656139, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.3012362719 time: 0.1796s
# Time Net =  2.7557742595672607
#
#
# MSE loss =  tensor(1.4053217683e-06, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.3015098274, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.3015084267 time: 0.2810s
# Time Net =  5.357088804244995
#
#
#
#
#  Graph number 3
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  632
# No.of edges =  2674
# adj_list =  torch.Size([2, 2674]) adj_mat =  torch.Size([632, 632])
# MSE loss =  tensor(1.1531773314e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0397778526, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0397778526 time: 0.2720s
# Time Net =  0.2720026969909668
#
#
# MSE loss =  tensor(1.0158363040e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0397778563, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0397778563 time: 0.3046s
# Time Net =  3.127107858657837
#
#
# MSE loss =  tensor(9.4093077774e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0397778563, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0397778563 time: 0.1510s
# Time Net =  5.83525013923645
#
#
#
#
#  Graph number 4
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  330
# No.of edges =  1091
# adj_list =  torch.Size([2, 1091]) adj_mat =  torch.Size([330, 330])
# MSE loss =  tensor(1.0054754807e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0550481826, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0550481826 time: 0.2130s
# Time Net =  0.21300029754638672
#
#
# MSE loss =  tensor(9.3816032720e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0550481826, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0550481826 time: 0.2900s
# Time Net =  2.934643268585205
#
#
# MSE loss =  tensor(8.8163965017e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0550481789, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0550481789 time: 0.2416s
# Time Net =  5.67185378074646
#
#
#
#
#  Graph number 5
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  31
# No.of edges =  88
# adj_list =  torch.Size([2, 88]) adj_mat =  torch.Size([31, 31])
# MSE loss =  tensor(1.2445076081e-08, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1796052605, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1796052456 time: 0.2650s
# Time Net =  0.2660059928894043
#
#
# MSE loss =  tensor(8.2156157433e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1796052754, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1796052605 time: 0.2740s
# Time Net =  2.844306707382202
#
#
# MSE loss =  tensor(5.3668571809e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1796052754, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1796052754 time: 0.2645s
# Time Net =  5.455060243606567
#
#
#
#
#  Graph number 6
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  20
# No.of edges =  37
# adj_list =  torch.Size([2, 37]) adj_mat =  torch.Size([20, 20])
# MSE loss =  tensor(6.8151622123e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2236067802, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2236067802 time: 0.2660s
# Time Net =  0.26700258255004883
#
#
# MSE loss =  tensor(3.7576870504e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2236068100, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2236068100 time: 0.2610s
# Time Net =  2.8325748443603516
#
#
# MSE loss =  tensor(2.0663875056e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2236067802, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2236067802 time: 0.2730s
# Time Net =  5.426781415939331
#
#
#
#
#  Graph number 7
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  17
# No.of edges =  17
# adj_list =  torch.Size([2, 17]) adj_mat =  torch.Size([17, 17])
# MSE loss =  tensor(4.7788201174e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356507, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2425356507 time: 0.2420s
# Time Net =  0.24299955368041992
#
#
# MSE loss =  tensor(3.4039995822e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356507, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2425356507 time: 0.2150s
# Time Net =  2.859797477722168
#
#
# MSE loss =  tensor(2.7385874124e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356209, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2425356209 time: 0.2611s
# Time Net =  5.375458478927612
#
#
#
#
#  Graph number 8
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  6
# No.of edges =  5
# adj_list =  torch.Size([2, 5]) adj_mat =  torch.Size([6, 6])
# MSE loss =  tensor(5.5244697705e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4082482755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.4082482755 time: 0.2430s
# Time Net =  0.24499797821044922
# MSE loss =  tensor(0., device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4082482755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.4082482755 time: 0.1780s
# Time Net =  2.590580463409424
#
#
# MSE loss =  tensor(0., device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4082482755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.4082482755 time: 0.1816s
# Time Net =  5.066709280014038
#
#
#
#
#  Graph number 9
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  27
# No.of edges =  27
# adj_list =  torch.Size([2, 27]) adj_mat =  torch.Size([27, 27])
# MSE loss =  tensor(2.1588518473e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1924501061, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1924501061 time: 0.1730s
# Time Net =  0.17399191856384277
#
#
# MSE loss =  tensor(1.2362286195e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1924500763, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1924500763 time: 0.2556s
# Time Net =  2.7257137298583984
#
#
# MSE loss =  tensor(6.6259733811e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1924500763, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1924500763 time: 0.0378s
# Time Net =  5.1127331256866455
#
#
#
#
#  Graph number 10
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  1435
# No.of edges =  7811
# adj_list =  torch.Size([2, 7811]) adj_mat =  torch.Size([1435, 1435])
# MSE loss =  tensor(1.5494745244e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0263981838, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0263981838 time: 0.2590s
# Time Net =  0.2600114345550537
#
#
# MSE loss =  tensor(1.3041844080e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0263981838, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0263981838 time: 0.1520s
# Time Net =  3.4585328102111816
#
#
# MSE loss =  tensor(1.2077590447e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0263981838, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0263981838 time: 0.2400s
# Time Net =  6.758685111999512
#
#
#
#
#  Graph number 11
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  496
# No.of edges =  3137
# adj_list =  torch.Size([2, 3137]) adj_mat =  torch.Size([496, 496])
# MSE loss =  tensor(3.0056365383e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0449013226, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0449013226 time: 0.2846s
# Time Net =  0.28557610511779785
#
#
# MSE loss =  tensor(2.6847981303e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0449013226, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0449013226 time: 0.2390s
# Time Net =  2.965733289718628
#
#
# MSE loss =  tensor(2.3806631579e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0449013226, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0449013226 time: 0.1520s
# Time Net =  5.711434602737427
#
#
#
#
#  Graph number 12
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  117
# No.of edges =  222
# adj_list =  torch.Size([2, 222]) adj_mat =  torch.Size([117, 117])
# MSE loss =  tensor(1.2061590442e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0924500301, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0924500301 time: 0.1890s
# Time Net =  0.1900005340576172
#
#
# MSE loss =  tensor(8.9581207036e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0924500376, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0924500376 time: 0.2330s
# Time Net =  2.783144474029541
#
#
# MSE loss =  tensor(6.3850803984e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0924500376, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0924500376 time: 0.1130s
# Time Net =  5.176738500595093
#
#
#
#
#  Graph number 13
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  675
# No.of edges =  3020
# adj_list =  torch.Size([2, 3020]) adj_mat =  torch.Size([675, 675])
# MSE loss =  tensor(5.5600522016e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0384900197, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0384900197 time: 0.1035s
# Time Net =  0.10452747344970703
#
#
# MSE loss =  tensor(4.7558642137e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0384900197, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0384900197 time: 0.2160s
# Time Net =  2.982682228088379
#
#
# MSE loss =  tensor(4.2269418759e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0384900197, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0384900197 time: 0.2150s
# Time Net =  5.710912466049194
#
#
#
#
#  Graph number 14
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  149
# No.of edges =  338
# adj_list =  torch.Size([2, 338]) adj_mat =  torch.Size([149, 149])
# MSE loss =  tensor(1.3704187524e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0819231942, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0819231942 time: 0.2770s
# Time Net =  0.2780022621154785
#
#
# MSE loss =  tensor(1.0292374591e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0819231942, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0819231942 time: 0.1455s
# Time Net =  2.8625948429107666
#
#
# MSE loss =  tensor(7.4307004777e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0819231942, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0819231942 time: 0.2590s
# Time Net =  5.476165771484375
#
#
#
#
#  Graph number 15
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  49
# No.of edges =  67
# adj_list =  torch.Size([2, 67]) adj_mat =  torch.Size([49, 49])
# MSE loss =  tensor(2.6669777498e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1428571343 time: 0.1972s
# Time Net =  0.19816875457763672
#
#
# MSE loss =  tensor(1.7008072468e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1428571343 time: 0.2500s
# Time Net =  2.7031474113464355
#
#
# MSE loss =  tensor(1.0281253930e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1428571343 time: 0.2600s
# Time Net =  5.326404094696045
#
#
#
#
#  Graph number 16
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  836
# No.of edges =  4605
# adj_list =  torch.Size([2, 4605]) adj_mat =  torch.Size([836, 836])
# MSE loss =  tensor(3.3598355946e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0345857218, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0345857218 time: 0.2160s
# Time Net =  0.21600675582885742
#
#
# MSE loss =  tensor(2.1141546376e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0345857218, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0345857218 time: 0.2220s
# Time Net =  3.1113903522491455
#
#
# MSE loss =  tensor(1.8294111716e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0345857218, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0345857218 time: 0.2120s
# Time Net =  5.782663822174072
#  Graph number 17
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  13
# No.of edges =  15
# adj_list =  torch.Size([2, 15]) adj_mat =  torch.Size([13, 13])
# MSE loss =  tensor(6.2274973589e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2773500979, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2773500979 time: 0.1870s
# Time Net =  0.18800663948059082
#
#
# MSE loss =  tensor(4.1662401068e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2773501277, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2773501277 time: 0.2605s
# Time Net =  2.630664110183716
#
#
# MSE loss =  tensor(2.5975803539e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2773501277, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2773501277 time: 0.2250s
# Time Net =  5.122767210006714
#
#
#
#
#  Graph number 18
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  278
# No.of edges =  1188
# adj_list =  torch.Size([2, 1188]) adj_mat =  torch.Size([278, 278])
# MSE loss =  tensor(2.4140611791e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0599760152, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0599760152 time: 0.2284s
# Time Net =  0.22995662689208984
#
#
# MSE loss =  tensor(2.1804301799e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0599760152, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0599760152 time: 0.1790s
# Time Net =  2.8420848846435547
#
#
# MSE loss =  tensor(1.7149101895e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0599760152, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0599760152 time: 0.2440s
# Time Net =  5.528634071350098
#
#
#
#
#  Graph number 19
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  132
# No.of edges =  131
# adj_list =  torch.Size([2, 131]) adj_mat =  torch.Size([132, 132])
# MSE loss =  tensor(2.7036455231e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0870388225, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0870388225 time: 0.0840s
# Time Net =  0.08500003814697266
#
#
# MSE loss =  tensor(1.9428902931e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0870388299, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0870388299 time: 0.1630s
# Time Net =  2.595130681991577
#
#
# MSE loss =  tensor(1.7675255680e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0870388299, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0870388299 time: 0.2600s
# Time Net =  5.294034957885742
#
#
#
#
#  Graph number 20
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  65
# No.of edges =  167
# adj_list =  torch.Size([2, 167]) adj_mat =  torch.Size([65, 65])
# MSE loss =  tensor(2.8370468596e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1240347326, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1240347326 time: 0.1490s
# Time Net =  0.14999985694885254
#
#
# MSE loss =  tensor(1.3151872631e-16, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1240347326, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1240347326 time: 0.1800s
# Time Net =  2.659209728240967
#
#
# MSE loss =  tensor(1.1870846471e-16, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1240347326, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1240347326 time: 0.2580s
# Time Net =  5.223341703414917
#
#
#
#
#  Graph number 21
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  658
# No.of edges =  2948
# adj_list =  torch.Size([2, 2948]) adj_mat =  torch.Size([658, 658])
# MSE loss =  tensor(5.8094783832e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0389840566, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0389840566 time: 0.2860s
# Time Net =  0.2859995365142822
#
#
# MSE loss =  tensor(4.8829145480e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0389840603, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0389840603 time: 0.2020s
# Time Net =  3.1237151622772217
#
#
# MSE loss =  tensor(4.0796266173e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0389840603, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0389840603 time: 0.2110s
# Time Net =  6.004353046417236
#
#
#
#
#  Graph number 22
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  5
# No.of edges =  4
# adj_list =  torch.Size([2, 4]) adj_mat =  torch.Size([5, 5])
# MSE loss =  tensor(3.0340175359e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4472135603, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.4472135603 time: 0.2780s
# Time Net =  0.27799463272094727
#
#
# MSE loss =  tensor(0., device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4472135603, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.4472135603 time: 0.1720s
# Time Net =  2.7971248626708984
#
#
# MSE loss =  tensor(3.5527137317e-16, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.4472135603, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.4472135603 time: 0.2710s
# Time Net =  5.453848600387573
#
#
#
#
#  Graph number 23
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  57
# No.of edges =  155
# adj_list =  torch.Size([2, 155]) adj_mat =  torch.Size([57, 57])
# MSE loss =  tensor(5.5740595516e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1324532479, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1324532479 time: 0.1836s
# Time Net =  0.18456530570983887
#
#
# MSE loss =  tensor(2.9554917541e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1324532330, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1324532330 time: 0.1310s
# Time Net =  2.585742712020874
#
#
# MSE loss =  tensor(1.4219035021e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1324532330, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1324532330 time: 0.2335s
# Time Net =  5.115907430648804
#
#
#
#
#  Graph number 24
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  481
# No.of edges =  1954
# adj_list =  torch.Size([2, 1954]) adj_mat =  torch.Size([481, 481])
# MSE loss =  tensor(1.2387255121e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0455960780, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0455960780 time: 0.2910s
# Time Net =  0.2930004596710205
#
#
# MSE loss =  tensor(1.0273102898e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0455960780, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0455960780 time: 0.2540s
# Time Net =  3.0022242069244385
#
#
# MSE loss =  tensor(7.6386434070e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0455960780, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0455960780 time: 0.1830s
# Time Net =  5.706519365310669
#
#
#
#
#  Graph number 25
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  1202
# No.of edges =  6209
# adj_list =  torch.Size([2, 6209]) adj_mat =  torch.Size([1202, 1202])
# MSE loss =  tensor(3.5799813634e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0288434867, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0288434867 time: 0.1430s
# Time Net =  0.14400959014892578
# MSE loss =  tensor(2.6546580079e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0288434830, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0288434830 time: 0.2300s
# Time Net =  3.356017589569092
#
#
# MSE loss =  tensor(2.2386013534e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0288434867, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0288434867 time: 0.2630s
# Time Net =  6.692018747329712
#
#
#
#
#  Graph number 26
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  24
# No.of edges =  45
# adj_list =  torch.Size([2, 45]) adj_mat =  torch.Size([24, 24])
# MSE loss =  tensor(8.0583692388e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2041241378, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2041241378 time: 0.2450s
# Time Net =  0.24500107765197754
#
#
# MSE loss =  tensor(6.9388939039e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2041241378, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2041241378 time: 0.2610s
# Time Net =  2.780113697052002
#
#
# MSE loss =  tensor(5.4743248102e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2041241527, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2041241527 time: 0.2220s
# Time Net =  5.321399688720703
#
#
#
#
#  Graph number 27
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  3
# No.of edges =  2
# adj_list =  torch.Size([2, 2]) adj_mat =  torch.Size([3, 3])
# MSE loss =  tensor(4.7369517129e-15, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.5773503184, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.5773503184 time: 0.0910s
# Time Net =  0.09099912643432617
#
#
# MSE loss =  tensor(0., device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.5773503184, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.5773503184 time: 0.1800s
# Time Net =  2.5781495571136475
#
#
# MSE loss =  tensor(0., device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.5773502588, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.5773502588 time: 0.1760s
# Time Net =  5.070985794067383
#
#
#
#
#  Graph number 28
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  44
# No.of edges =  112
# adj_list =  torch.Size([2, 112]) adj_mat =  torch.Size([44, 44])
# MSE loss =  tensor(2.4872530251e-13, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1507556736, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1507556736 time: 0.2216s
# Time Net =  0.22163677215576172
#
#
# MSE loss =  tensor(6.6073408138e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1507556736, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1507556736 time: 0.2870s
# Time Net =  2.6892459392547607
#
#
# MSE loss =  tensor(1.1097184471e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1507556885, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1507556885 time: 0.2380s
# Time Net =  5.145251750946045
#
#
#
#
#  Graph number 29
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  378
# No.of edges =  2287
# adj_list =  torch.Size([2, 2287]) adj_mat =  torch.Size([378, 378])
# MSE loss =  tensor(6.5838976523e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0514344499, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0514344499 time: 0.0690s
# Time Net =  0.07000064849853516
#
#
# MSE loss =  tensor(4.8208825983e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0514344461, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0514344461 time: 0.1825s
# Time Net =  2.7163825035095215
#
#
# MSE loss =  tensor(3.1825365639e-14, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0514344499, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0514344499 time: 0.2320s
# Time Net =  5.366218566894531

# %%
print(loss_plot)
np.save("result_eigen/loss/l2",loss_plot)
torch.save(model.state_dict(), "result_eigen/"+dataset+".pt")
writer = pd.ExcelWriter("result_eigen/rt-retweet-crawl_gcn.xlsx", engine = 'xlsxwriter')
df = pd.DataFrame(list(zip(l5,l10,l15,l20)),columns=["Top-5%","Top-10%","Top-15%","Top-20%"])
df.to_excel(writer)
writer.save()
writer.close()
# Out:
# []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 torch.save(model.state_dict(), "result_eigen/"+dataset+".pt")
#       4 writer = pd.ExcelWriter("result_eigen/rt-retweet-crawl_gcn.xlsx", engine = 'xlsxwriter')
# ----> 5 df = pd.DataFrame(list(zip(l5,l10,l15,l20)),columns=["Top-5%","Top-10%","Top-15%","Top-20%"])
#       6 df.to_excel(writer)
#       7 writer.save()
#
# NameError: name 'l5' is not defined
