# %%
#%matplotlib inline

import matplotlib.pyplot as plt

import numpy as np
import torch
from torch.nn.parameter import Parameter
import torch.optim as optim
import torch.nn.functional as F
import torch.nn as nn
import networkx as nx
import time
import os.path as osp
from collections import defaultdict
import pandas as pd
import xlsxwriter
from torch_geometric.nn import GCNConv,GATConv, SGConv, BatchNorm,SAGEConv
torch.manual_seed(29)
# cit-DBLP：13.24.27.29.40.44.46
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
torch.set_printoptions(precision=10)
gra_train = "scale"
path_train = "data/"+gra_train
path_test = "data/"

dataset = "cit-DBLP"

# %%
def data_process(g, mode="test"):
  
    adj = list(g.edges())
    m = g.number_of_nodes()

    features = torch.zeros(size=(m,1)).float()
    
    print("No.of nodes = ",m)
    print("No.of edges = ",g.number_of_edges())

    for u,_ in adj:
        features[u,0]+=1

    features = features/max(features)
    adj = torch.LongTensor(adj).t().contiguous()
 
    if mode == "train":
        
        adj_mat = torch.from_numpy(nx.to_numpy_array(g))
        adj_mat = F.normalize(adj_mat, p=1,dim=1).float()
        
        return adj.to(device), features.to(device), adj_mat.to(device)
    
    else:
        return adj.to(device), features.to(device)

# %%
def eigen_vector_calc(adj_mat, y):
    
    z = torch.spmm(adj_mat,y)
    y = y / (torch.linalg.norm(y))
    z = z/ (torch.linalg.norm(z))
    
    return y,z

# %%
class Model(nn.Module):
    def __init__(self, nin, nhid1, nout, hid_l, out_l=1):
        super(Model, self).__init__()
        
        self.gc1 = SAGEConv(in_channels= nin, out_channels= nhid1)
        self.bc1 = BatchNorm(nhid1)
        self.gc2 = SAGEConv(in_channels= nhid1, out_channels= nout)
        self.bc2 = BatchNorm(nhid1)
        self.lay1 = nn.Linear(nout ,hid_l)
        self.l0 = nn.Linear(hid_l,hid_l)
        self.lb0 = nn.BatchNorm1d(hid_l)
        self.l1 = nn.Linear(hid_l,hid_l)
        self.lb1 = nn.BatchNorm1d(hid_l)
        self.lay2 = nn.Linear(hid_l ,out_l)
        self.active1 = nn.LeakyReLU(0.1)
        
        with torch.no_grad():
            self.gc1.weight = Parameter(nn.init.uniform_(torch.empty(nin,nhid1),a=0.0,b=1.0))
            self.gc1.bias = Parameter(nn.init.uniform_(torch.empty(nhid1),a=0.0,b=1.0))
            self.gc2.weight = Parameter(nn.init.uniform_(torch.empty(nhid1,nout),a=0.0,b=1.0))
            self.gc2.bias = Parameter(nn.init.uniform_(torch.empty(nout),a=0.0,b=1.0))
            self.lay1.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, nout ),a=0.0,b=1.0))
            self.l0.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, hid_l),a=0.0,b=1.0))
            self.l1.weight = Parameter(nn.init.uniform_(torch.empty(hid_l, hid_l),a=0.0,b=1.0))
            self.lay2.weight = Parameter(nn.init.uniform_(torch.empty(out_l,hid_l),a=0.0,b=1.0))


    def forward(self, x, adj):
        x = self.gc1(x, adj)
        x = self.bc1(x)
        x = self.gc2(x, adj)
        x = self.bc2(x)
        x = self.lay1(x)
        x = self.l0(x)
        x = self.lb0(x)
        x = self.l1(x)
        x = self.lb1(x)
        x = self.lay2(x)
        
        return self.active1(x)

# %%
def train_model(epoch):
    model.train()
    optimizer.zero_grad()
    t = time.time()
    y = model(features,adj)
    
    y,z = eigen_vector_calc(adj_mat, y)
    
    loss1 = nn.MSELoss()(y,z)
    loss2 = -y.abs().mean()
    loss_train = loss1 + loss2
    loss_temp.append(loss_train.cpu().detach())
    
    loss_train.backward(retain_graph=True)
    optimizer.step()
    
    if epoch%50==0:
        print("MSE loss = ",loss1,"\t","Mean Loss = ",loss2)
        print('Epoch: {:04d}'.format(epoch+1),
                  'loss_train: {:.10f}'.format(loss_train.item()),
                  'time: {:.4f}s'.format(time.time() - t))
        

    return y

# %%
if __name__=="__main__":
    
    #Training

    loss_plot = []
    
    model= Model(nin = 1, nhid1=128, nout=128, hid_l=64, out_l=1).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr = 0.001)
    #flag = False
    g = nx.read_weighted_edgelist(osp.join(path_test, dataset+".edgelist"),nodetype=int)
    no_of_nodes = g.number_of_nodes()
    
    for i in range(40):
        print("\n\n Graph number",i,"\n","-"*120)
        #if flag: break
        
        samples = np.random.randint(low=0, high=no_of_nodes)

        g_subgraph = nx.bfs_tree(g, source=samples, depth_limit=2)
        map = dict( list(zip(list(g_subgraph.nodes()), list(range(g_subgraph.number_of_nodes())))))
        g_subgraph = g.subgraph(g_subgraph)
        g_subgraph = nx.relabel_nodes(g_subgraph,map)
        #g = nx.read_edgelist(osp.join(path_train,gra_train+"_1k/"+gra_train+"1k_"+str(i)),nodetype=int)
        adj,features,adj_mat = data_process(g_subgraph ,mode="train")
        print("adj_list = ",adj.shape,"adj_mat = ",adj_mat.shape)

        loss_temp=[]
        net_time = time.time()
        
        for ep in range(150):
            y = train_model(ep)
            if ep%50==0:
                print("Time Net = ",time.time()-net_time,"\n\n")
                '''
                print("{:^10}".format("-------Validation-------"))
                l5, l10, l15, l20 = [],[],[],[]
                test(g)
                if l5[0]>0.5 and l10>0.55:
                  flag = True
                  break
                '''
        loss_plot.append((np.mean(loss_temp), i))
# Out:
#  Graph number 0
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  47
# No.of edges =  72
# adj_list =  torch.Size([2, 72]) adj_mat =  torch.Size([47, 47])
# MSE loss =  tensor(0.0318271443, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0892385095, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0574113652 time: 0.0130s
# Time Net =  0.01399993896484375
#
#
# MSE loss =  tensor(0.0354900695, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0968431905, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0613531210 time: 0.0060s
# Time Net =  0.3489987850189209
#
#
# MSE loss =  tensor(0.0310775414, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0944052711, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0633277297 time: 0.0100s
# Time Net =  0.6085772514343262
#
#
#
#
#  Graph number 1
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  20
# No.of edges =  30
# adj_list =  torch.Size([2, 30]) adj_mat =  torch.Size([20, 20])
# MSE loss =  tensor(0.0254320502, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1470983773, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1216663271 time: 0.0060s
# Time Net =  0.007009267807006836
#
#
# MSE loss =  tensor(0.0318430364, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1618710309, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1300279945 time: 0.0060s
# Time Net =  0.23529958724975586
#
#
# MSE loss =  tensor(0.0324141793, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1628297567, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1304155737 time: 0.0080s
# Time Net =  0.4602994918823242
#
#
#
#
#  Graph number 2
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  8
# No.of edges =  8
# adj_list =  torch.Size([2, 8]) adj_mat =  torch.Size([8, 8])
# MSE loss =  tensor(0.2310367525, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1448018551, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: 0.0862348974 time: 0.0060s
# Time Net =  0.005991458892822266
#
#
# MSE loss =  tensor(0.0622330867, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.3299927115, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2677596211 time: 0.0050s
# Time Net =  0.2229909896850586
#
#
# MSE loss =  tensor(0.0611810237, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.3293401003, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2681590915 time: 0.0080s
# Time Net =  0.4369640350341797
#
#
#
#
#  Graph number 3
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  44
# No.of edges =  60
# adj_list =  torch.Size([2, 60]) adj_mat =  torch.Size([44, 44])
# MSE loss =  tensor(0.0172889661, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1224633455, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1051743776 time: 0.0060s
# Time Net =  0.007000923156738281
#
#
# MSE loss =  tensor(0.0160500668, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1258149147, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1097648442 time: 0.0080s
# Time Net =  0.21999907493591309
#
#
# MSE loss =  tensor(0.0139765423, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1312444657, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1172679216 time: 0.0080s
# Time Net =  0.4370391368865967
#
#
#
#
#  Graph number 4
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  11
# No.of edges =  12
# adj_list =  torch.Size([2, 12]) adj_mat =  torch.Size([11, 11])
# MSE loss =  tensor(0.2404361069, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1386979967, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: 0.1017381102 time: 0.0050s
# Time Net =  0.0049953460693359375
#
#
# MSE loss =  tensor(0.0971610323, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1678976119, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0707365796 time: 0.0080s
# Time Net =  0.21650075912475586
#
#
# MSE loss =  tensor(0.0954127759, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1668790132, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0714662373 time: 0.0060s
# Time Net =  0.4244997501373291
#
#
#
#
#  Graph number 5
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  333
# No.of edges =  1671
# adj_list =  torch.Size([2, 1671]) adj_mat =  torch.Size([333, 333])
# MSE loss =  tensor(0.0034416819, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0294605233, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0260188412 time: 0.0090s
# Time Net =  0.009999752044677734
#
#
# MSE loss =  tensor(0.0033936081, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0300461091, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0266525000 time: 0.0070s
# Time Net =  0.26599979400634766
#
#
# MSE loss =  tensor(0.0033137111, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0308755469, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0275618359 time: 0.0050s
# Time Net =  0.5155477523803711
#
#
#
#
#  Graph number 6
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  28
# No.of edges =  83
# adj_list =  torch.Size([2, 83]) adj_mat =  torch.Size([28, 28])
# MSE loss =  tensor(0.0536603779, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0953691378, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0417087600 time: 0.0090s
# Time Net =  0.008995294570922852
#
#
# MSE loss =  tensor(0.0318816751, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1343014985, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1024198234 time: 0.0050s
# Time Net =  0.23099422454833984
#
#
# MSE loss =  tensor(0.0003146337, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1882676333, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1879529953 time: 0.0080s
# Time Net =  0.45499730110168457
#
#
#
#
#  Graph number 7
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  129
# No.of edges =  428
# adj_list =  torch.Size([2, 428]) adj_mat =  torch.Size([129, 129])
# MSE loss =  tensor(1.3817452782e-07, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0880444422, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0880443007 time: 0.0060s
# Time Net =  0.007005929946899414
#
#
# MSE loss =  tensor(2.7910365130e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0880450755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0880450755 time: 0.0050s
# Time Net =  0.23299932479858398
#
#
# MSE loss =  tensor(1.6701282024e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0880450904, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0880450904 time: 0.0050s
# Time Net =  0.45099759101867676
#
#
#
#
#  Graph number 8
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  12
# No.of edges =  12
# adj_list =  torch.Size([2, 12]) adj_mat =  torch.Size([12, 12])
# MSE loss =  tensor(4.5867473708e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2886751592, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2886751592 time: 0.0060s
# Time Net =  0.006000041961669922
#
#
# MSE loss =  tensor(4.4992151671e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2886751592, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2886751592 time: 0.0148s
# Time Net =  0.3067796230316162
#
#
# MSE loss =  tensor(4.4078629635e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2886751592, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2886751592 time: 0.0080s
# Time Net =  0.5807783603668213
#
#
#
#
#  Graph number 9
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  413
# No.of edges =  2056
# adj_list =  torch.Size([2, 2056]) adj_mat =  torch.Size([413, 413])
# MSE loss =  tensor(1.9848074573e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0492067859, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0492067859 time: 0.0100s
# Time Net =  0.010997533798217773
#
#
# MSE loss =  tensor(1.9841010779e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0492067859, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0492067859 time: 0.0060s
# Time Net =  0.29000306129455566
#
#
# MSE loss =  tensor(1.9831197448e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0492067859, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0492067859 time: 0.0060s
# Time Net =  0.5855674743652344
#
#
#
#
#  Graph number 10
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  602
# No.of edges =  2875
# adj_list =  torch.Size([2, 2875]) adj_mat =  torch.Size([602, 602])
# MSE loss =  tensor(2.3271013588e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0407569520, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0407569520 time: 0.0230s
# Time Net =  0.022999048233032227
#
#
# MSE loss =  tensor(2.3259370124e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0407569520, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0407569520 time: 0.0090s
# Time Net =  0.44455909729003906
#
#
# MSE loss =  tensor(2.3246427353e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0407569520, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0407569520 time: 0.0080s
# Time Net =  0.708561897277832
#
#
#
#
#  Graph number 11
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  1263
# No.of edges =  6862
# adj_list =  torch.Size([2, 6862]) adj_mat =  torch.Size([1263, 1263])
# MSE loss =  tensor(5.5491557530e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0281383302, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0281383302 time: 0.0370s
# Time Net =  0.03800058364868164
#
#
# MSE loss =  tensor(5.5488604163e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0281383302, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0281383302 time: 0.0060s
# Time Net =  0.523998498916626
#
#
# MSE loss =  tensor(5.5464920851e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0281383302, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0281383302 time: 0.0120s
# Time Net =  0.8549978733062744
#
#
#
#
#  Graph number 12
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  17
# No.of edges =  22
# adj_list =  torch.Size([2, 22]) adj_mat =  torch.Size([17, 17])
# MSE loss =  tensor(5.7683243598e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356209, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2425356209 time: 0.0090s
# Time Net =  0.010001659393310547
#
#
# MSE loss =  tensor(5.7374015261e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356507, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2425356507 time: 0.0080s
# Time Net =  0.2566862106323242
#
#
# MSE loss =  tensor(5.6926789671e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356507, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2425356507 time: 0.0060s
# Time Net =  0.5123369693756104
#
#
#
#
#  Graph number 13
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  30
# No.of edges =  43
# adj_list =  torch.Size([2, 43]) adj_mat =  torch.Size([30, 30])
# MSE loss =  tensor(5.4428356266e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741827, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1825741827 time: 0.0060s
# Time Net =  0.005995035171508789
#
#
# MSE loss =  tensor(5.2017168350e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741827, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1825741827 time: 0.0050s
# Time Net =  0.25899434089660645
#
#
# MSE loss =  tensor(5.1763809905e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741827, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1825741827 time: 0.0050s
# Time Net =  0.5255649089813232
#
#
#
#
#  Graph number 14
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  55
# No.of edges =  145
# adj_list =  torch.Size([2, 145]) adj_mat =  torch.Size([55, 55])
# MSE loss =  tensor(3.5732825032e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1348399669, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1348399669 time: 0.0050s
# Time Net =  0.007006645202636719
#
#
# MSE loss =  tensor(3.5580319246e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1348399669, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1348399669 time: 0.0070s
# Time Net =  0.2570047378540039
#
#
# MSE loss =  tensor(3.5495936745e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1348399669, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1348399669 time: 0.0100s
# Time Net =  0.545677661895752
#
#
#
#
#  Graph number 15
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  162
# No.of edges =  696
# adj_list =  torch.Size([2, 696]) adj_mat =  torch.Size([162, 162])
# MSE loss =  tensor(1.2625157864e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0785674155, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0785674155 time: 0.0090s
# Time Net =  0.008999824523925781
#
#
# MSE loss =  tensor(1.2461080778e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0785674229, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0785674229 time: 0.0050s
# Time Net =  0.28600382804870605
#
#
# MSE loss =  tensor(1.2431290719e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0785674229, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0785674229 time: 0.0090s
# Time Net =  0.5091252326965332
#
#
#
#
#  Graph number 16
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  63
# No.of edges =  102
# adj_list =  torch.Size([2, 102]) adj_mat =  torch.Size([63, 63])
# MSE loss =  tensor(8.1374074146e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1259881705, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1259881705 time: 0.0100s
# Time Net =  0.011012554168701172
#
#
# MSE loss =  tensor(8.0725627571e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1259881705, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1259881705 time: 0.0090s
# Time Net =  0.26302170753479004
#
#
# MSE loss =  tensor(8.0547651882e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1259881705, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1259881705 time: 0.0090s
# Time Net =  0.5130341053009033
#
#
#
#
#  Graph number 17
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  127
# No.of edges =  389
# adj_list =  torch.Size([2, 389]) adj_mat =  torch.Size([127, 127])
# MSE loss =  tensor(1.0972820569e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0887356400, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0887356400 time: 0.0110s
# Time Net =  0.010999441146850586
#
#
# MSE loss =  tensor(1.0959756019e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0887356475, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0887356475 time: 0.0080s
# Time Net =  0.24234533309936523
#
#
# MSE loss =  tensor(1.0941952205e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0887356550, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0887356550 time: 0.0050s
# Time Net =  0.46183156967163086
#
#
#
#
#  Graph number 18
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  653
# No.of edges =  3417
# adj_list =  torch.Size([2, 3417]) adj_mat =  torch.Size([653, 653])
# MSE loss =  tensor(1.4393665079e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0391330272, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0391330272 time: 0.0100s
# Time Net =  0.009999275207519531
#
#
# MSE loss =  tensor(1.4387556251e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0391330235, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0391330235 time: 0.0060s
# Time Net =  0.2649989128112793
#
#
# MSE loss =  tensor(1.4378085528e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0391330272, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0391330272 time: 0.0050s
# Time Net =  0.4856264591217041
#
#
#
#
#  Graph number 19
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  159
# No.of edges =  192
# adj_list =  torch.Size([2, 192]) adj_mat =  torch.Size([159, 159])
# MSE loss =  tensor(7.6762811385e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0793051571, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0793051571 time: 0.0060s
# Time Net =  0.006000041961669922
#
#
# MSE loss =  tensor(7.2967569487e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0793051571, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0793051571 time: 0.0050s
# Time Net =  0.21699976921081543
#
#
# MSE loss =  tensor(7.2769693049e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0793051571, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0793051571 time: 0.0050s
# Time Net =  0.47227954864501953
#
#
#
#
#  Graph number 20
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  30
# No.of edges =  31
# adj_list =  torch.Size([2, 31]) adj_mat =  torch.Size([30, 30])
# MSE loss =  tensor(3.4912750468e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741976, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1825741976 time: 0.0060s
# Time Net =  0.006000041961669922
#
#
# MSE loss =  tensor(3.3562561064e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741976, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1825741976 time: 0.0060s
# Time Net =  0.21739888191223145
#
#
# MSE loss =  tensor(3.3425678891e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1825741827, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1825741827 time: 0.0090s
# Time Net =  0.4303007125854492
#
#
#
#
#  Graph number 21
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  76
# No.of edges =  142
# adj_list =  torch.Size([2, 142]) adj_mat =  torch.Size([76, 76])
# MSE loss =  tensor(9.5396558708e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1147078574, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1147078574 time: 0.0070s
# Time Net =  0.008000373840332031
#
#
# MSE loss =  tensor(9.4753725699e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1147078723, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1147078723 time: 0.0050s
# Time Net =  0.21900010108947754
#
#
# MSE loss =  tensor(9.4678952178e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1147078574, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1147078574 time: 0.0110s
# Time Net =  0.4477255344390869
#
#
#
#
#  Graph number 22
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  160
# No.of edges =  702
# adj_list =  torch.Size([2, 702]) adj_mat =  torch.Size([160, 160])
# MSE loss =  tensor(4.3190246518e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0790569410, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0790569410 time: 0.0090s
# Time Net =  0.009000539779663086
#
#
# MSE loss =  tensor(4.2961967317e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0790569410, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0790569410 time: 0.0090s
# Time Net =  0.24200057983398438
#
#
# MSE loss =  tensor(4.2904953895e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0790569410, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0790569410 time: 0.0050s
# Time Net =  0.4679992198944092
#
#
#
#
#  Graph number 23
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  16
# No.of edges =  41
# adj_list =  torch.Size([2, 41]) adj_mat =  torch.Size([16, 16])
# MSE loss =  tensor(1.6275872872e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2499999851, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2499999851 time: 0.0060s
# Time Net =  0.0059986114501953125
#
#
# MSE loss =  tensor(1.5947682064e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2499999702, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2499999702 time: 0.0060s
# Time Net =  0.2259986400604248
#
#
# MSE loss =  tensor(1.5693508715e-09, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2500000000, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2500000000 time: 0.0090s
# Time Net =  0.44899797439575195
#
#
#
#
#  Graph number 24
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  14
# No.of edges =  15
# adj_list =  torch.Size([2, 15]) adj_mat =  torch.Size([14, 14])
# MSE loss =  tensor(6.7244848578e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2672612369, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2672612369 time: 0.0070s
# Time Net =  0.006989002227783203
#
#
# MSE loss =  tensor(6.6563105028e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2672612369, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2672612369 time: 0.0060s
# Time Net =  0.22658181190490723
#
#
# MSE loss =  tensor(6.5910898961e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2672612369, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2672612369 time: 0.0060s
# Time Net =  0.44158172607421875
#
#
#
#
#  Graph number 25
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  49
# No.of edges =  100
# adj_list =  torch.Size([2, 100]) adj_mat =  torch.Size([49, 49])
# MSE loss =  tensor(1.8334377072e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1428571343 time: 0.0050s
# Time Net =  0.004999399185180664
#
#
# MSE loss =  tensor(1.8091325660e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1428571343 time: 0.0060s
# Time Net =  0.2199997901916504
#
#
# MSE loss =  tensor(1.8016485526e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1428571343 time: 0.0080s
# Time Net =  0.43100428581237793
#
#
#
#
#  Graph number 26
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  26
# No.of edges =  31
# adj_list =  torch.Size([2, 31]) adj_mat =  torch.Size([26, 26])
# MSE loss =  tensor(1.4743142818e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1961161196, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1961161196 time: 0.0050s
# Time Net =  0.006003856658935547
#
#
# MSE loss =  tensor(1.4483877986e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1961161196, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1961161196 time: 0.0050s
# Time Net =  0.21599960327148438
#
#
# MSE loss =  tensor(1.4334596010e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1961161196, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1961161196 time: 0.0070s
# Time Net =  0.4259328842163086
#
#
#
#
#  Graph number 27
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  433
# No.of edges =  1908
# adj_list =  torch.Size([2, 1908]) adj_mat =  torch.Size([433, 433])
# MSE loss =  tensor(1.8191576717e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0480569303, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0480569303 time: 0.0050s
# Time Net =  0.005999088287353516
#
#
# MSE loss =  tensor(1.8045315242e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0480569303, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0480569303 time: 0.0050s
# Time Net =  0.23554539680480957
#
#
# MSE loss =  tensor(1.8021808004e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0480569303, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0480569303 time: 0.0070s
# Time Net =  0.47054481506347656
#
#
#
#
#  Graph number 28
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  115
# No.of edges =  417
# adj_list =  torch.Size([2, 417]) adj_mat =  torch.Size([115, 115])
# MSE loss =  tensor(6.1792168604e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0932504758, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0932504758 time: 0.0050s
# Time Net =  0.005000114440917969
#
#
# MSE loss =  tensor(6.1668919971e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0932504758, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0932504758 time: 0.0050s
# Time Net =  0.25299978256225586
#
#
# MSE loss =  tensor(6.1538399376e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0932504833, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0932504833 time: 0.0100s
# Time Net =  0.48199915885925293
#
#
#
#
#  Graph number 29
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  112
# No.of edges =  439
# adj_list =  torch.Size([2, 439]) adj_mat =  torch.Size([112, 112])
# MSE loss =  tensor(1.0275370832e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0944911316, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0944911316 time: 0.0080s
# Time Net =  0.009000539779663086
#
#
# MSE loss =  tensor(1.0175194715e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0944911316, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0944911316 time: 0.0090s
# Time Net =  0.22700023651123047
#
#
# MSE loss =  tensor(1.0149457663e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0944911316, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0944911316 time: 0.0090s
# Time Net =  0.4439997673034668
#
#
#
#
#  Graph number 30
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  16
# No.of edges =  27
# adj_list =  torch.Size([2, 27]) adj_mat =  torch.Size([16, 16])
# MSE loss =  tensor(4.4932785270e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2500000000, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2500000000 time: 0.0070s
# Time Net =  0.008007287979125977
#
#
# MSE loss =  tensor(4.4065256999e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2500000000, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2500000000 time: 0.0080s
# Time Net =  0.22423911094665527
#
#
# MSE loss =  tensor(4.3203918221e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2500000000, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2500000000 time: 0.0050s
# Time Net =  0.4342353343963623
#
#
#
#
#  Graph number 31
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  1049
# No.of edges =  6069
# adj_list =  torch.Size([2, 6069]) adj_mat =  torch.Size([1049, 1049])
# MSE loss =  tensor(4.5255162465e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0308753755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0308753755 time: 0.0350s
# Time Net =  0.03600001335144043
#
#
# MSE loss =  tensor(4.5200206425e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0308753755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0308753755 time: 0.0050s
# Time Net =  0.40856432914733887
#
#
# MSE loss =  tensor(4.5192122614e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0308753755, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0308753755 time: 0.0060s
# Time Net =  0.6935641765594482
#
#
#
#
#  Graph number 32
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  917
# No.of edges =  4776
# adj_list =  torch.Size([2, 4776]) adj_mat =  torch.Size([917, 917])
# MSE loss =  tensor(7.0967225152e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0330229104, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0330229104 time: 0.0280s
# Time Net =  0.029000043869018555
#
#
# MSE loss =  tensor(7.0886196218e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0330229104, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0330229104 time: 0.0100s
# Time Net =  0.46268796920776367
#
#
# MSE loss =  tensor(7.0834813709e-12, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0330229066, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0330229066 time: 0.0060s
# Time Net =  0.7306876182556152
#
#
#
#
#  Graph number 33
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  19
# No.of edges =  37
# adj_list =  torch.Size([2, 37]) adj_mat =  torch.Size([19, 19])
# MSE loss =  tensor(4.7597314978e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157445, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2294157445 time: 0.0050s
# Time Net =  0.0049991607666015625
#
#
# MSE loss =  tensor(4.6826070799e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157445, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2294157445 time: 0.0100s
# Time Net =  0.2506594657897949
#
#
# MSE loss =  tensor(4.6036779944e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157147, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2294157147 time: 0.0060s
# Time Net =  0.5046594142913818
#
#
#
#
#  Graph number 34
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  19
# No.of edges =  38
# adj_list =  torch.Size([2, 38]) adj_mat =  torch.Size([19, 19])
# MSE loss =  tensor(9.1673363345e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157445, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2294157445 time: 0.0060s
# Time Net =  0.006992340087890625
#
#
# MSE loss =  tensor(8.8965607103e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157147, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2294157147 time: 0.0050s
# Time Net =  0.2249925136566162
#
#
# MSE loss =  tensor(8.7745205546e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2294157445, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2294157445 time: 0.0090s
# Time Net =  0.4379920959472656
#
#
#
#
#  Graph number 35
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  17
# No.of edges =  18
# adj_list =  torch.Size([2, 18]) adj_mat =  torch.Size([17, 17])
# MSE loss =  tensor(2.2171754710e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356209, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.2425356209 time: 0.0110s
# Time Net =  0.01100301742553711
#
#
# MSE loss =  tensor(2.1005620854e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356507, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.2425356507 time: 0.0060s
# Time Net =  0.2629992961883545
#
#
# MSE loss =  tensor(2.0706467097e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.2425356209, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.2425356209 time: 0.0070s
# Time Net =  0.47899889945983887
#
#
#
#
#  Graph number 36
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  49
# No.of edges =  117
# adj_list =  torch.Size([2, 117]) adj_mat =  torch.Size([49, 49])
# MSE loss =  tensor(7.0422556675e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1428571343 time: 0.0050s
# Time Net =  0.00600433349609375
#
#
# MSE loss =  tensor(6.1739019452e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1428571343 time: 0.0080s
# Time Net =  0.21459722518920898
#
#
# MSE loss =  tensor(6.0328864127e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1428571343, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1428571343 time: 0.0060s
# Time Net =  0.41959595680236816
#
#
#
#
#  Graph number 37
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  184
# No.of edges =  612
# adj_list =  torch.Size([2, 612]) adj_mat =  torch.Size([184, 184])
# MSE loss =  tensor(4.5650136449e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0737209767, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0737209767 time: 0.0050s
# Time Net =  0.004996538162231445
#
#
# MSE loss =  tensor(4.3978938546e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0737209767, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0737209767 time: 0.0060s
# Time Net =  0.2350008487701416
#
#
# MSE loss =  tensor(4.3869755051e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0737209767, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0737209767 time: 0.0050s
# Time Net =  0.4490044116973877
#
#
#
#
#  Graph number 38
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  32
# No.of edges =  48
# adj_list =  torch.Size([2, 48]) adj_mat =  torch.Size([32, 32])
# MSE loss =  tensor(2.6216592786e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1767766774, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.1767766774 time: 0.0060s
# Time Net =  0.006003141403198242
#
#
# MSE loss =  tensor(2.5329016662e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1767766923, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.1767766923 time: 0.0060s
# Time Net =  0.25299978256225586
#
#
# MSE loss =  tensor(2.5089941236e-10, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.1767766923, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.1767766923 time: 0.0050s
# Time Net =  0.48400211334228516
#
#
#
#
#  Graph number 39
#  ------------------------------------------------------------------------------------------------------------------------
# No.of nodes =  475
# No.of edges =  2055
# adj_list =  torch.Size([2, 2055]) adj_mat =  torch.Size([475, 475])
# MSE loss =  tensor(1.2158284796e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0458831452, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0001 loss_train: -0.0458831452 time: 0.0060s
# Time Net =  0.00599980354309082
#
#
# MSE loss =  tensor(1.2065091981e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0458831452, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0051 loss_train: -0.0458831452 time: 0.0050s
# Time Net =  0.2422952651977539
#
#
# MSE loss =  tensor(1.2055262170e-11, device='cuda:0', grad_fn=<MseLossBackward0>) 	 Mean Loss =  tensor(-0.0458831452, device='cuda:0', grad_fn=<NegBackward0>)
# Epoch: 0101 loss_train: -0.0458831452 time: 0.0090s
# Time Net =  0.4672963619232178

# %%
print(loss_plot)
np.save("result_eigen/loss/l2",loss_plot)
torch.save(model.state_dict(), "result_eigen/"+dataset+".pt")
writer = pd.ExcelWriter("result_eigen/rt-retweet-crawl_gcn.xlsx", engine = 'xlsxwriter')
print(model.forward)
# df = pd.DataFrame(list(zip(l5,l10,l15,l20)),columns=["Top-5%","Top-10%","Top-15%","Top-20%"])
# df.to_excel(writer)
# writer.save()
# writer.close()
# Out:
# [(-0.06223817, 0), (-0.12991361, 1), (-0.26361963, 2), (-0.11330232, 3), (-0.0622764, 4), (-0.027166385, 5), (-0.13787411, 6), (-0.0880448, 7), (-0.28867513, 8), (-0.049206786, 9), (-0.040756956, 10), (-0.028138332, 11), (-0.24253565, 12), (-0.18257417, 13), (-0.13483997, 14), (-0.07856742, 15), (-0.12598816, 16), (-0.08873565, 17), (-0.039133027, 18), (-0.079305165, 19), (-0.18257417, 20), (-0.11470787, 21), (-0.07905693, 22), (-0.25, 23), (-0.26726124, 24), (-0.14285715, 25), (-0.19611615, 26), (-0.048056927, 27), (-0.09325047, 28), (-0.09449112, 29), (-0.25, 30), (-0.030875377, 31), (-0.03302291, 32), (-0.22941574, 33), (-0.22941574, 34), (-0.24253565, 35), (-0.14285715, 36), (-0.073720984, 37), (-0.1767767, 38), (-0.045883145, 39)]
# <bound method Model.forward of Model(
#   (gc1): SAGEConv(1, 128, aggr=mean)
#   (bc1): BatchNorm(128)
#   (gc2): SAGEConv(128, 128, aggr=mean)
#   (bc2): BatchNorm(128)
#   (lay1): Linear(in_features=128, out_features=64, bias=True)
#   (l0): Linear(in_features=64, out_features=64, bias=True)
#   (lb0): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (l1): Linear(in_features=64, out_features=64, bias=True)
#   (lb1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lay2): Linear(in_features=64, out_features=1, bias=True)
#   (active1): LeakyReLU(negative_slope=0.1)
# )>
